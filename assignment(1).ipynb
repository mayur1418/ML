# %% [markdown]
# **ASSIGNMENT 1**

# %% [markdown]
# SUBTRACTION

# %%
a=10
b=3
dif=a-b
print(dif)
# Out:
# 7

# %% [markdown]
# PRODUCT

# %%
m=23
n=32
mul=m*n
print(mul)
# Out:
# 736

# %% [markdown]
# DIVISION

# %%
p=9
q=3

div=p//q
rem=p%q
print(div)
print(rem)
# Out:
# 3
# 0

# %% [markdown]
# SQURING

# %%
x=5
squ=x*x
print(squ)
# Out:
# 25

# %% [markdown]
# SQUARE ROOT

# %%
x=16
sq=x**(1/2)
print(sq)
# Out:
# 4.0

# %% [markdown]
# GREATER

# %%
a=5
b=6
print(max(a,b))
# Out:
# 6

# %% [markdown]
# TYPE OF DATA

# %%
name="MAYUR@123"
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# LIST DATA TYPE

# %%
lis=['mayur','patil']
lis1=['sky','abc']
print(type(lis))
print(type(lis1))
lis2=lis1+lis
print(lis2)
lis1.append("all is well")
print(lis1)
lis1.clear()
print(lis1)
lis3=['mayur','patil','maruti']
lis3[2]
lis3.sort()
lis3
lis1.sort
print(lis1)
# Out:
# <class 'list'>
# <class 'list'>
# ['sky', 'abc', 'mayur', 'patil']
# ['sky', 'abc', 'all is well']
# []
# []

# %% [markdown]
# TUPPLE

# %%
tuple1="mayur",)
print(type(tuple1))
# Out:
# <class 'list'>

# %% [markdown]
# # Python program to check if the input number is odd or even.
# # A number is even if division by 2 gives a remainder of 0.
# # If the remainder is 1, it is an odd number.

# %%
num = int(input("Enter a number: "))
if (num % 2) == 0:
   print("{0} is Even".format(num))
else:
   print("{0} is Odd".format(num))
# Out:
# Enter a number: 8
# 8 is Even

# %% [markdown]
# # Python program to swap two variables

# %%
x = 5
y = 10

# To take inputs from the user
#x = input('Enter value of x: ')
#y = input('Enter value of y: ')

# create a temporary variable and swap the values
temp = x
x = y
y = temp

print('The value of x after swapping: {}'.format(x))
print('The value of y after swapping: {}'.format(y))
# Out:
# The value of x after swapping: 10
# The value of y after swapping: 5

# %% [markdown]
# maximum

# %%
def maximum(a,b):

    if a>=b:
        return a
    else:
        return b

# Driver code
a = 2
b = 4
print(maximum(a,b))
# Out:
# 4

# %% [markdown]
# DICTIONARY

# %%
dictionary_1={'MAYUR':14}
dictionary_2={'KLE TECH':1}
# Adding the 2 dictionary
di_3= dictionary_1 | dictionary_2
print(di_3)
# Changing the value with help of key
dictionary_1['PATIL']=81
print(dictionary_1)
# Out:
# {'MAYUR': 14, 'KLE TECH': 1}
# {'MAYUR': 14, 'PATIL': 81}

# %% [markdown]
# CHECK THE NUMBER IN LIST

# %%
list1=[123,154,176,1888,2000]
number=int(input('Enter Any Number To Check It Is In The List Or Not :'))
if list1[0]==number:
  print('Entered Number Is In The List')
elif list[1]==number:
   print('Entered Number Is In The List')
elif list[2]==number:
   print('Entered Number Is In The List')
elif list[3]==number:
   print('Entered Number Is In The List')
else:
  print('Entered Number Is Not In The List')
# Out:
# Enter Any Number To Check It Is In The List Or Not :8
# Entered Number Is In The List
